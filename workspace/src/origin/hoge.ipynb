# %%
import pandas as pd 
houseData=pd.read_csv("../data/csvData/bostonhousing.csv")

# %%
houseData
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax  \
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 451  5.44114   0.0  18.10     0  0.713  6.655  98.2  2.3552   24  666
# 452  5.09017   0.0  18.10     0  0.713  6.297  91.8  2.3682   24  666
# 453  8.24809   0.0  18.10     0  0.713  7.393  99.3  2.4527   24  666
# 454  9.51363   0.0  18.10     0  0.713  6.728  94.1  2.4961   24  666
# 455  4.75237   0.0  18.10     0  0.713  6.525  86.5  2.4358   24  666
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
houseData.describe()
# Out:
#              crim          zn       indus        chas         nox          rm  \
# count  456.000000  456.000000  456.000000  456.000000  456.000000  456.000000
# mean     3.546267   12.609649   10.482763    0.076754    0.548866    6.307235
# std      8.955170   24.247964    6.732356    0.266494    0.119362    0.722355
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.074383    0.000000    4.930000    0.000000    0.447000    5.887750
# 50%      0.223505    0.000000    8.140000    0.000000    0.520000    6.224500
# 75%      2.256870   20.000000   18.100000    0.000000    0.624000    6.636750
# max     88.976200  100.000000   25.650000    1.000000    0.871000    8.780000
#
#               age         dis         rad         tax     ptratio           b  \
# count  456.000000  456.000000  456.000000  456.000000  456.000000  456.000000
# mean    67.666228    3.917517    8.752193  388.614035   18.274123  356.737763
# ...

# %%
houseData.iloc[0:10, [0,1,2]]
# Out:
#       crim    zn  indus
# 0  0.00632  18.0   2.31
# 1  0.02731   0.0   7.07
# 2  0.02729   0.0   7.07
# 3  0.03237   0.0   2.18
# 4  0.06905   0.0   2.18
# 5  0.02985   0.0   2.18
# 6  0.08829  12.5   7.87
# 7  0.14455  12.5   7.87
# 8  0.21124  12.5   7.87
# 9  0.17004  12.5   7.87

# %%
houseData.loc[:, ['crim', 'age']]
# Out:
#         crim   age
# 0    0.00632  65.2
# 1    0.02731  78.9
# 2    0.02729  61.1
# 3    0.03237  45.8
# 4    0.06905  54.2
# ..       ...   ...
# 451  5.44114  98.2
# 452  5.09017  91.8
# 453  8.24809  99.3
# 454  9.51363  94.1
# 455  4.75237  86.5
#
# [456 rows x 2 columns]

# %%
import matplotlib.pyplot as plt

# %%
houseData.loc[0:10, ['lstat', 'medv']].plot.bar()
# Out:
# <AxesSubplot:>

# %%
houseData.loc[:, ['medv']].plot.hist()
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
houseData.loc[:, ['zn', 'crim', 'age', 'lstat', 'medv']].plot.box()
# Out:
# <AxesSubplot:>

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minMaxScaler = MinMaxScaler()
scaledData = minMaxScaler.fit_transform(houseData.iloc[:, :])

scaledData = pd.DataFrame(scaledData, columns=houseData.columns)

# %%
scaledData
# Out:
#          crim    zn     indus  chas       nox        rm       age       dis  \
# 0    0.000000  0.18  0.073442   0.0  0.314815  0.577505  0.641607  0.269203
# 1    0.000236  0.00  0.262406   0.0  0.172840  0.547998  0.782698  0.348962
# 2    0.000236  0.00  0.262406   0.0  0.172840  0.694386  0.599382  0.348962
# 3    0.000293  0.00  0.068281   0.0  0.150206  0.658555  0.441813  0.448545
# 4    0.000705  0.00  0.068281   0.0  0.150206  0.687105  0.528321  0.448545
# ..        ...   ...       ...   ...       ...       ...       ...       ...
# 451  0.061086  0.00  0.700278   0.0  0.674897  0.592834  0.981462  0.111450
# 452  0.057141  0.00  0.700278   0.0  0.674897  0.524238  0.915551  0.112632
# 453  0.092636  0.00  0.700278   0.0  0.674897  0.734240  0.992791  0.120316
# 454  0.106860  0.00  0.700278   0.0  0.674897  0.606821  0.939238  0.124262
# 455  0.053344  0.00  0.700278   0.0  0.674897  0.567925  0.860968  0.118779
#
# ...

# %%
from sklearn.preprocessing import OneHotEncoder

# %%
imcomedata = pd.read_csv('../data/csvData/incomedata.csv')

# %%
ohe = OneHotEncoder(categories='auto')

educationData = incomedata.loc[:, ['Education']]
encodedEduData = ohe.fit_transform(educationData).toarray()

pd.DataFrame
